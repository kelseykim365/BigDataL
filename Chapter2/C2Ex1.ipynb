# %%
import findspark
findspark.init()
import pyspark

# %%
from pyspark import SparkContext
sc = SparkContext(master='local', appName='Ex1 Spark Context')
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/25 21:30:19 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/06/25 21:30:19 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/06/25 21:30:33 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
file_name = "/Users/kaylakim/Documents/BigData/t8.shakespeare.txt"
data = sc.textFile(file_name).cache()
print("Lines: %i" % (len(data.collect())))
# Out:
# Lines: 124185

# %%
numLoves = data.filter(lambda s: 'love' in s).count()
print("Lines with 'love': %i" % (numLoves))
# Out:
# Lines with 'love': 2484
# 25/06/26 00:04:58 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 826645 ms exceeds timeout 120000 ms
# 25/06/26 00:04:58 WARN SparkContext: Killing executors is not supported by current scheduler.
# 25/06/26 00:05:02 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# ...
